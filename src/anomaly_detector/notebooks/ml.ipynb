# %%
import pandas as pd
import numpy as np

df_conn = pd.read_json("conn.log", lines=True)
df_dns  = pd.read_json("dns.log", lines=True)
df_tls  = pd.read_json("ssl.log", lines=True)
df_http  = pd.read_json("http.log", lines=True)
